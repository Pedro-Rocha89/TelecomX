# %% [markdown]
# #📌 Extracão

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json'

# %%
# Extraindo o banco de dados
dados = pd.read_json(url)
dados
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
# Criando o DataFrame
df_dados = pd.DataFrame(dados)
df_dados
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %% [markdown]
# #🔧 Transformação

# %% [markdown]
# #### Analisando os dados

# %%
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df_dados.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
df_dados.isnull().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
# Normalizando as colunas
colunas_customer = pd.json_normalize(df_dados['customer'])
colunas_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
colunas_phone = pd.json_normalize(df_dados['phone'])
colunas_phone
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
colunas_internet = pd.json_normalize(df_dados['internet'])
colunas_internet
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
colunas_account = pd.json_normalize(df_dados['account'])
colunas_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
df_normalizado = pd.concat([df_dados,colunas_customer,colunas_phone,colunas_internet,colunas_account],axis=1)
df_normalizado.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
colunas_removidas = ['customer','account','phone','internet']

# %%
df_final = df_normalizado.drop(columns=colunas_removidas)
df_final
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
df_final.isnull().sum()
# Out:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
df_final.duplicated().any()
# Out:
# np.False_

# %%
df_final.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
for i in df_final.columns:
  print(f"--- Coluna: '{i}' ---")
  print(df_final[i].unique())
# Out:
# --- Coluna: 'customerID' ---
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# --- Coluna: 'Churn' ---
# ['No' 'Yes' '']
# --- Coluna: 'gender' ---
# ['Female' 'Male']
# --- Coluna: 'SeniorCitizen' ---
# [0 1]
# --- Coluna: 'Partner' ---
# ['Yes' 'No']
# --- Coluna: 'Dependents' ---
# ['Yes' 'No']
# --- Coluna: 'tenure' ---
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
# --- Coluna: 'PhoneService' ---
# ['Yes' 'No']
# --- Coluna: 'MultipleLines' ---
# ['No' 'Yes' 'No phone service']
# --- Coluna: 'InternetService' ---
# ['DSL' 'Fiber optic' 'No']
# --- Coluna: 'OnlineSecurity' ---
# ['No' 'Yes' 'No internet service']
# --- Coluna: 'OnlineBackup' ---
# ['Yes' 'No' 'No internet service']
# --- Coluna: 'DeviceProtection' ---
# ['No' 'Yes' 'No internet service']
# ...

# %% [markdown]
# Na coluna 'Churn', principal coluna de análise, existem dados faltantes (''). Portanto, devemos excluí-los

# %%
df_final['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64

# %%
df_final = df_final[df_final['Churn'] != '']
df_final.reset_index(drop=True, inplace=True)
df_final
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7038  9987-LUTYD    No  Female              0      No         No      13
# 7039  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7040  9992-UJOEL    No    Male              0      No         No       2
# 7041  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7042  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
df_final['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# Outra coluna que apresenta dados vazios (' ') é a Charges.Total. Essa coluna tem uma relação com Charges.Monthly e tenure.
#
# A coluna tenure representa a quantidade de meses em que o cliente estava assinando o serviço. A coluna Charges.Monthly representa os gastos mensais do cliente e Charges.Total é a quantidade total de gastos, portanto seria uma multiplicação de Charges.Monthly por tenure.
#
# Vamos selecionar todas as linhas onde o tenure = 0, ou seja, os clientes que assinaram o serviço por 0 meses, e mostrar os resultados para as colunas Charges.Total e Charges.Monthly.

# %%
df_final['Charges.Total'].value_counts()
# Out:
# Charges.Total
# 20.2       11
#            11
# 19.75       9
# 19.9        8
# 19.65       8
#            ..
# 829.55      1
# 625.65      1
# 462.8       1
# 251.25      1
# 3121.45     1
# Name: count, Length: 6531, dtype: int64

# %%
df_final.query('tenure == 0')[['Charges.Total', 'Charges.Monthly', 'tenure']]
# Out:
#      Charges.Total  Charges.Monthly  tenure
# 945                           56.05       0
# 1731                          20.00       0
# 1906                          61.90       0
# 2025                          19.70       0
# 2176                          20.25       0
# 2250                          25.35       0
# 2855                          73.35       0
# 3052                          25.75       0
# 3118                          52.55       0
# 4054                          80.85       0
# 5433                          19.85       0

# %% [markdown]
# Verificamos que quando tenure = 0, os dados de Charges.Total é vazio (' ').
#
# Vamos agora selecionar os dados onde Charges.Total = ' ', mostrando os resultados para Charges.Monthly e tenure.

# %%
df_final[df_final['Charges.Total'] == ' '][['Charges.Total', 'Charges.Monthly', 'tenure']]
# Out:
#      Charges.Total  Charges.Monthly  tenure
# 945                           56.05       0
# 1731                          20.00       0
# 1906                          61.90       0
# 2025                          19.70       0
# 2176                          20.25       0
# 2250                          25.35       0
# 2855                          73.35       0
# 3052                          25.75       0
# 3118                          52.55       0
# 4054                          80.85       0
# 5433                          19.85       0

# %% [markdown]
# Percebe-se que todas as linhas de Charges.Total que estão vazias é porque o cliente não assinou nem por um mês. Temos que preencher esse valor com o mesmo valor que está presente em "Charges.Monthly" pois esse representa o total.

# %%
idx = df_final[df_final['Charges.Total'] == ' '].index
df_final.loc[idx, "Charges.Total"] = df_final.loc[idx, "Charges.Monthly"]

# %%
df_final.query('tenure == 0')[['Charges.Total', 'Charges.Monthly', 'tenure']]
# Out:
#      Charges.Total  Charges.Monthly  tenure
# 945          56.05            56.05       0
# 1731          20.0            20.00       0
# 1906          61.9            61.90       0
# 2025          19.7            19.70       0
# 2176         20.25            20.25       0
# 2250         25.35            25.35       0
# 2855         73.35            73.35       0
# 3052         25.75            25.75       0
# 3118         52.55            52.55       0
# 4054         80.85            80.85       0
# 5433         19.85            19.85       0

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %% [markdown]
# Por fim, vamos modificar o tipo da variável para float, uma vez que o tipo estava como object.

# %%
df_final['Charges.Total'] = df_final['Charges.Total'].astype('float64')
# Out:
# /tmp/ipython-input-30-2153807216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Charges.Total'] = df_final['Charges.Total'].astype('float64')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Churn             7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
# ...

# %% [markdown]
# #### Criando a Conta Diária

# %%
# Criando a coluna "Contas_Diarias"
df_final['Charges.diary'] = df_final['Charges.Monthly']/30
# Out:
# /tmp/ipython-input-32-2274981510.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Charges.diary'] = df_final['Charges.Monthly']/30

# %%
df_final
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7038  9987-LUTYD    No  Female              0      No         No      13
# 7039  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7040  9992-UJOEL    No    Male              0      No         No       2
# 7041  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7042  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# ...

# %% [markdown]
# #### Padronizando os Dados

# %%
# Lista de colunas para mapear 'Yes'/'No' para 1/0
colunas_sim_nao = [
    'Partner',
    'Dependents',
    'PaperlessBilling',
    'Churn'
]

for col in colunas_sim_nao:
    df_final[col] = df_final[col].replace({'Yes': 1, 'No': 0})
# Out:
# /tmp/ipython-input-34-487568972.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_final[col] = df_final[col].replace({'Yes': 1, 'No': 0})
# /tmp/ipython-input-34-487568972.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[col] = df_final[col].replace({'Yes': 1, 'No': 0})

# %%
# Colunas que podem ter 'No internet service' ou 'No phone service'
colunas_servico = [
    'MultipleLines',
    'OnlineSecurity',
    'OnlineBackup',
    'DeviceProtection',
    'TechSupport',
    'StreamingTV',
    'StreamingMovies'
]

for col in colunas_servico:
    df_final[col] = df_final[col].replace({
        'Yes': 1,
        'No': 0,
        'No internet service': 0,
        'No phone service': 0
    })
# Out:
# /tmp/ipython-input-35-1642514862.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_final[col] = df_final[col].replace({
# /tmp/ipython-input-35-1642514862.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[col] = df_final[col].replace({

# %%
# A coluna 'PhoneService' é binária 'Yes'/'No'
df_final['PhoneService'] = df_final['PhoneService'].replace({'Yes': 1, 'No': 0})
# Out:
# /tmp/ipython-input-36-1078238966.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_final['PhoneService'] = df_final['PhoneService'].replace({'Yes': 1, 'No': 0})
# /tmp/ipython-input-36-1078238966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['PhoneService'] = df_final['PhoneService'].replace({'Yes': 1, 'No': 0})

# %%
# Verificando os tipos e valores únicos após a transformação
print("Tipos de dados após a transformação:")
print(df_final[colunas_sim_nao + colunas_servico + ['PhoneService']].dtypes)

print("\nValores únicos após a transformação:")
for col in colunas_sim_nao + colunas_servico + ['PhoneService']:
    print(f"- {col}: {df_final[col].unique()}")
# Out:
# Tipos de dados após a transformação:
# Partner             int64
# Dependents          int64
# PaperlessBilling    int64
# Churn               int64
# MultipleLines       int64
# OnlineSecurity      int64
# OnlineBackup        int64
# DeviceProtection    int64
# TechSupport         int64
# StreamingTV         int64
# StreamingMovies     int64
# PhoneService        int64
# dtype: object
#
# Valores únicos após a transformação:
# - Partner: [1 0]
# - Dependents: [1 0]
# - PaperlessBilling: [1 0]
# - Churn: [0 1]
# - MultipleLines: [0 1]
# - OnlineSecurity: [0 1]
# - OnlineBackup: [1 0]
# - DeviceProtection: [0 1]
# - TechSupport: [1 0]
# - StreamingTV: [1 0]
# - StreamingMovies: [0 1]
# - PhoneService: [1 0]

# %%
df_final.head()
# Out:
#    customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  0002-ORFBO      0  Female              0        1           1       9
# 1  0003-MKNFE      0    Male              0        0           0       9
# 2  0004-TLHLJ      1    Male              0        0           0       4
# 3  0011-IGKFF      1    Male              1        1           0      13
# 4  0013-EXCHZ      1  Female              1        1           0       3
#
#    PhoneService  MultipleLines InternetService  ...  DeviceProtection  \
# 0             1              0             DSL  ...                 0
# 1             1              1             DSL  ...                 0
# 2             1              0     Fiber optic  ...                 1
# 3             1              0     Fiber optic  ...                 1
# 4             1              0     Fiber optic  ...                 0
#
#    TechSupport  StreamingTV  StreamingMovies        Contract  \
# ...

# %% [markdown]
# #### Traduzindo as colunas

# %%
# Dicionário de mapeamento atualizado para renomear as colunas
novos_nomes_colunas = {
    'customerID': 'id_cliente',
    'gender': 'genero',
    'SeniorCitizen': 'eh_cidadao_senior',
    'Partner': 'tem_parceiro',
    'Dependents': 'tem_dependentes',
    'tenure': 'meses_de_servico',
    'PhoneService': 'servico_telefone',
    'MultipleLines': 'multiplas_linhas',
    'InternetService': 'servico_internet',
    'OnlineSecurity': 'seguranca_online',
    'OnlineBackup': 'backup_online',
    'DeviceProtection': 'protecao_dispositivo',
    'TechSupport': 'suporte_tecnico',
    'StreamingTV': 'streaming_tv',
    'StreamingMovies': 'streaming_filmes',
    'Contract': 'tipo_contrato',
    'PaperlessBilling': 'fatura_online',
    'PaymentMethod': 'metodo_pagamento',
    'Charges.Monthly': 'gastos_mensais',
    'Charges.Total': 'gastos_totais',
    'Churn': 'cancelou_servico',
    'Charges.diary': 'gastos_diarios'
}

# Renomeando as colunas no DataFrame
df_final = df_final.rename(columns=novos_nomes_colunas)

# Verificando os novos nomes das colunas para confirmar
print("Novos nomes das colunas:")
print(df_final.columns)
# Out:
# Novos nomes das colunas:
# Index(['id_cliente', 'cancelou_servico', 'genero', 'eh_cidadao_senior',
#        'tem_parceiro', 'tem_dependentes', 'meses_de_servico',
#        'servico_telefone', 'multiplas_linhas', 'servico_internet',
#        'seguranca_online', 'backup_online', 'protecao_dispositivo',
#        'suporte_tecnico', 'streaming_tv', 'streaming_filmes', 'tipo_contrato',
#        'fatura_online', 'metodo_pagamento', 'gastos_mensais', 'gastos_totais',
#        'gastos_diarios'],
#       dtype='object')

# %%
df_final.head()
# Out:
#    id_cliente  cancelou_servico  genero  eh_cidadao_senior  tem_parceiro  \
# 0  0002-ORFBO                 0  Female                  0             1
# 1  0003-MKNFE                 0    Male                  0             0
# 2  0004-TLHLJ                 1    Male                  0             0
# 3  0011-IGKFF                 1    Male                  1             1
# 4  0013-EXCHZ                 1  Female                  1             1
#
#    tem_dependentes  meses_de_servico  servico_telefone  multiplas_linhas  \
# 0                1                 9                 1                 0
# 1                0                 9                 1                 1
# 2                0                 4                 1                 0
# 3                0                13                 1                 0
# 4                0                 3                 1                 0
#
#   servico_internet  ...  protecao_dispositivo  suporte_tecnico  streaming_tv  \
# ...

# %% [markdown]
# #📊 Carga e análise

# %% [markdown]
# #### Análise Descritiva

# %% [markdown]
# Colunas Numéricas

# %%
print("--- Estatísticas Descritivas para Colunas Numéricas ---")
print(df_final[['meses_de_servico', 'gastos_mensais', 'gastos_totais', 'gastos_diarios']].describe())
# Out:
# --- Estatísticas Descritivas para Colunas Numéricas ---
#        meses_de_servico  gastos_mensais  gastos_totais  gastos_diarios
# count       7043.000000     7043.000000    7043.000000     7043.000000
# mean          32.371149       64.761692    2279.798992        2.158723
# std           24.559481       30.090047    2266.730170        1.003002
# min            0.000000       18.250000      18.800000        0.608333
# 25%            9.000000       35.500000     398.550000        1.183333
# 50%           29.000000       70.350000    1394.550000        2.345000
# 75%           55.000000       89.850000    3786.600000        2.995000
# max           72.000000      118.750000    8684.800000        3.958333

# %% [markdown]
# Colunas Categóricas

# %%
print("\n--- Frequência para Colunas Categóricas e Binárias ---")
colunas_categoricas = [
    'genero', 'eh_cidadao_senior', 'tem_parceiro', 'tem_dependentes',
    'servico_telefone', 'multiplas_linhas', 'servico_internet',
    'seguranca_online', 'backup_online', 'protecao_dispositivo',
    'suporte_tecnico', 'streaming_tv', 'streaming_filmes',
    'tipo_contrato', 'fatura_online', 'metodo_pagamento', 'cancelou_servico'
]

for col in colunas_categoricas:
    print(f"\n--- Coluna: '{col}' ---")
    print(df_final[col].value_counts())
    print(df_final[col].value_counts(normalize=True).mul(100).round(2).astype(str) + '%')
# Out:
# --- Frequência para Colunas Categóricas e Binárias ---
#
# --- Coluna: 'genero' ---
# genero
# Male      3555
# Female    3488
# Name: count, dtype: int64
# genero
# Male      50.48%
# Female    49.52%
# Name: proportion, dtype: object
#
# --- Coluna: 'eh_cidadao_senior' ---
# eh_cidadao_senior
# 0    5901
# 1    1142
# Name: count, dtype: int64
# eh_cidadao_senior
# 0    83.79%
# 1    16.21%
# Name: proportion, dtype: object
#
# --- Coluna: 'tem_parceiro' ---
# tem_parceiro
# 0    3641
# 1    3402
# Name: count, dtype: int64
# tem_parceiro
# 0    51.7%
# 1    48.3%
# Name: proportion, dtype: object
#
# --- Coluna: 'tem_dependentes' ---
# tem_dependentes
# 0    4933
# 1    2110
# Name: count, dtype: int64
# tem_dependentes
# 0    70.04%
# 1    29.96%
# Name: proportion, dtype: object
#
# --- Coluna: 'servico_telefone' ---
# servico_telefone
# 1    6361
# 0     682
# Name: count, dtype: int64
# servico_telefone
# 1    90.32%
# 0     9.68%
# Name: proportion, dtype: object
#
# ...

# %% [markdown]
# #### Distribuição da Evasão

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configurações para melhorar a visualização dos gráficos
sns.set_style("whitegrid")
plt.figure(figsize=(6, 5))

# Contagem dos valores da coluna 'cancelou_servico'
churn_counts = df_final['cancelou_servico'].value_counts()

# Calculando as porcentagens
churn_percentages = df_final['cancelou_servico'].value_counts(normalize=True) * 100

# Criando o gráfico de barras
sns.barplot(x=churn_counts.index, y=churn_counts.values, palette='viridis')

# Adicionando os rótulos aos eixos
plt.xlabel('Cancelou Serviço (Churn)')
plt.ylabel('Número de Clientes')
plt.title('Distribuição de Clientes por Cancelamento de Serviço')

# Ajustando o limite superior do eixo Y para criar mais espaço
max_count = churn_counts.max()
plt.ylim(0, max_count * 1.15)

# Adicionando os valores e porcentagens em cima das barras
for i, count in enumerate(churn_counts.values):
    plt.text(i, count + (max_count * 0.03),
             f'{count}\n({churn_percentages.iloc[i]:.2f}%)',
             ha='center', va='bottom', fontsize=10)

# Mapeando os rótulos do eixo X para serem mais descritivos
plt.xticks(ticks=[0, 1], labels=['Não Cancelou (0)', 'Cancelou (1)'])

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-63-3027065798.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=churn_counts.index, y=churn_counts.values, palette='viridis')

# %% [markdown]
# #### Analisando a Evasão por Variáveis Categóricas

# %% [markdown]
#  Por Gênero

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(8, 6))

ax = sns.countplot(data=df_final, x='genero', hue='cancelou_servico', palette='coolwarm')

plt.xlabel('Gênero')
plt.ylabel('Número de Clientes')
plt.title('Distribuição de Cancelamento por Gênero')

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=['Não Cancelou', 'Cancelou'])

max_count = df_final['genero'].value_counts().max()
plt.ylim(0, max_count * 1.20)

for p in ax.patches:
    height = p.get_height()
    if height > 0:
        x_val_center = (p.get_x() + p.get_x() + p.get_width()) / 2
        genero_idx = round(x_val_center)

        current_genero_label = ax.get_xticklabels()[genero_idx].get_text()

        total_por_genero = df_final['genero'].value_counts()[current_genero_label]

        percentage = (height / total_por_genero) * 100

        ax.text(p.get_x() + p.get_width() / 2,
                height + (ax.get_ylim()[1] * 0.02),
                f'{int(height)}\n({percentage:.1f}%)',
                ha='center', va='bottom', fontsize=9, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# Por Tipo de Serviço de Internet

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(9, 6))

ax = sns.countplot(data=df_final, x='servico_internet', hue='cancelou_servico', palette='coolwarm')

plt.xlabel('Serviço de Internet')
plt.ylabel('Número de Clientes')
plt.title('Distribuição de Cancelamento por Serviço de Internet')

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=['Não Cancelou', 'Cancelou'])

# Ajustando o limite Y para evitar sobreposição do texto
max_count = df_final['servico_internet'].value_counts().max()
plt.ylim(0, max_count * 1.20)

for p in ax.patches:
    height = p.get_height()
    if height > 0:
        # Pegando o rótulo da categoria do eixo X
        x_val_center = (p.get_x() + p.get_x() + p.get_width()) / 2
        # Identificando o índice do grupo (categoria do eixo X)
        x_tick_index = min(range(len(ax.get_xticklabels())), key=lambda i: abs(ax.get_xticks()[i] - x_val_center))
        current_category_label = ax.get_xticklabels()[x_tick_index].get_text()

        # Calculando o total de clientes para essa categoria específica
        total_por_categoria = df_final['servico_internet'].value_counts()[current_category_label]

        percentage = (height / total_por_categoria) * 100

        ax.text(p.get_x() + p.get_width() / 2,
                height + (ax.get_ylim()[1] * 0.02),
                f'{int(height)}\n({percentage:.1f}%)',
                ha='center', va='bottom', fontsize=9, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# Por Tipo de Contrato

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(9, 6))

ax = sns.countplot(data=df_final, x='tipo_contrato', hue='cancelou_servico', palette='coolwarm')

plt.xlabel('Tipo de Contrato')
plt.ylabel('Número de Clientes')
plt.title('Distribuição de Cancelamento por Tipo de Contrato')

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=['Não Cancelou', 'Cancelou'])

max_count = df_final['tipo_contrato'].value_counts().max()
plt.ylim(0, max_count * 1.20)

for p in ax.patches:
    height = p.get_height()
    if height > 0:
        x_val_center = (p.get_x() + p.get_x() + p.get_width()) / 2
        x_tick_index = min(range(len(ax.get_xticklabels())), key=lambda i: abs(ax.get_xticks()[i] - x_val_center))
        current_category_label = ax.get_xticklabels()[x_tick_index].get_text()

        total_por_categoria = df_final['tipo_contrato'].value_counts()[current_category_label]

        percentage = (height / total_por_categoria) * 100

        ax.text(p.get_x() + p.get_width() / 2,
                height + (ax.get_ylim()[1] * 0.02),
                f'{int(height)}\n({percentage:.1f}%)',
                ha='center', va='bottom', fontsize=9, color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# Por Método de Pagamento

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))

ax = sns.countplot(data=df_final, x='metodo_pagamento', hue='cancelou_servico', palette='coolwarm')

plt.xlabel('Método de Pagamento')
plt.ylabel('Número de Clientes')
plt.title('Distribuição de Cancelamenton por Método de Pagamento')

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=['Não Cancelou', 'Cancelou'])

max_count = df_final['metodo_pagamento'].value_counts().max()
plt.ylim(0, max_count * 1.20)

for p in ax.patches:
    height = p.get_height()
    if height > 0:
        x_val_center = (p.get_x() + p.get_x() + p.get_width()) / 2
        x_tick_index = min(range(len(ax.get_xticklabels())), key=lambda i: abs(ax.get_xticks()[i] - x_val_center))
        current_category_label = ax.get_xticklabels()[x_tick_index].get_text()

        total_por_categoria = df_final['metodo_pagamento'].value_counts()[current_category_label]

        percentage = (height / total_por_categoria) * 100

        ax.text(p.get_x() + p.get_width() / 2,
                height + (ax.get_ylim()[1] * 0.02),
                f'{int(height)}\n({percentage:.1f}%)',
                ha='center', va='bottom', fontsize=9, color='black')

plt.xticks(rotation=15, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Por ser Cidadão Senior

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(7, 6))

ax = sns.countplot(data=df_final, x='eh_cidadao_senior', hue='cancelou_servico', palette='coolwarm')

plt.xlabel('É Cidadão Sênior')
plt.ylabel('Número de Clientes')
plt.title('Distribuição de Cancelamento por Cidadão Sênior')

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=['Não Cancelou', 'Cancelou'])

max_count = df_final['eh_cidadao_senior'].value_counts().max()
plt.ylim(0, max_count * 1.20)

for p in ax.patches:
    height = p.get_height()
    if height > 0:
        x_val_center = (p.get_x() + p.get_x() + p.get_width()) / 2
        x_tick_index = min(range(len(ax.get_xticklabels())), key=lambda i: abs(ax.get_xticks()[i] - x_val_center))
        current_category_label = ax.get_xticklabels()[x_tick_index].get_text()

        # Como eh_cidadao_senior já é 0 ou 1, ajustamos o rótulo para o display
        if current_category_label == '0':
            display_label = 'Não'
        else:
            display_label = 'Sim'

        total_por_categoria = df_final['eh_cidadao_senior'].value_counts()[int(current_category_label)]
        percentage = (height / total_por_categoria) * 100

        ax.text(p.get_x() + p.get_width() / 2,
                height + (ax.get_ylim()[1] * 0.02),
                f'{int(height)}\n({percentage:.1f}%)',
                ha='center', va='bottom', fontsize=9, color='black')

plt.xticks(ticks=[0, 1], labels=['Não', 'Sim'])
plt.tight_layout()
plt.show()

# %% [markdown]
# Por Parceria

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(7, 6))

ax = sns.countplot(data=df_final, x='tem_parceiro', hue='cancelou_servico', palette='coolwarm')

plt.xlabel('Tem Parceiro')
plt.ylabel('Número de Clientes')
plt.title('Distribuição de Cancelamento por Ter Parceiro')

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=['Não Cancelou', 'Cancelou'])

max_count = df_final['tem_parceiro'].value_counts().max()
plt.ylim(0, max_count * 1.20)

for p in ax.patches:
    height = p.get_height()
    if height > 0:
        x_val_center = (p.get_x() + p.get_x() + p.get_width()) / 2
        x_tick_index = min(range(len(ax.get_xticklabels())), key=lambda i: abs(ax.get_xticks()[i] - x_val_center))
        current_category_label = ax.get_xticklabels()[x_tick_index].get_text()

        total_por_categoria = df_final['tem_parceiro'].value_counts()[int(current_category_label)]

        percentage = (height / total_por_categoria) * 100

        ax.text(p.get_x() + p.get_width() / 2,
                height + (ax.get_ylim()[1] * 0.02),
                f'{int(height)}\n({percentage:.1f}%)',
                ha='center', va='bottom', fontsize=9, color='black')

plt.xticks(ticks=[0, 1], labels=['Não', 'Sim'])
plt.tight_layout()
plt.show()

# %% [markdown]
# Por Dependente

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(7, 6))

ax = sns.countplot(data=df_final, x='tem_dependentes', hue='cancelou_servico', palette='coolwarm')

plt.xlabel('Tem Dependentes')
plt.ylabel('Número de Clientes')
plt.title('Distribuição de Cancelamento por Ter Dependentes')

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=['Não Cancelou', 'Cancelou'])

max_count = df_final['tem_dependentes'].value_counts().max()
plt.ylim(0, max_count * 1.20)

for p in ax.patches:
    height = p.get_height()
    if height > 0:
        x_val_center = (p.get_x() + p.get_x() + p.get_width()) / 2
        x_tick_index = min(range(len(ax.get_xticklabels())), key=lambda i: abs(ax.get_xticks()[i] - x_val_center))
        current_category_label = ax.get_xticklabels()[x_tick_index].get_text()

        total_por_categoria = df_final['tem_dependentes'].value_counts()[int(current_category_label)]

        percentage = (height / total_por_categoria) * 100

        ax.text(p.get_x() + p.get_width() / 2,
                height + (ax.get_ylim()[1] * 0.02),
                f'{int(height)}\n({percentage:.1f}%)',
                ha='center', va='bottom', fontsize=9, color='black')

plt.xticks(ticks=[0, 1], labels=['Não', 'Sim'])
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Analisando a Evasão por Variáveis Numéricas

# %% [markdown]
# Por Meses de Serviço

# %%
# Histograma Superposto
plt.figure(figsize=(10, 6))
sns.histplot(data=df_final, x='meses_de_servico', hue='cancelou_servico',
             multiple='stack', palette='coolwarm', kde=True)
plt.xlabel('Meses de Serviço')
plt.ylabel('Contagem de Clientes')
plt.title('Distribuição de Meses de Serviço por Cancelamento (Histograma)')
plt.legend(labels=['Cancelou', 'Não Cancelou'])
plt.tight_layout()
plt.show()

# KDE Plot (Gráfico de Densidade)
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df_final, x='meses_de_servico', hue='cancelou_servico',
            fill=True, common_norm=False, palette='coolwarm')
plt.xlabel('Meses de Serviço')
plt.ylabel('Densidade')
plt.title('Distribuição de Densidade de Meses de Serviço por Cancelamento')
plt.legend(labels=['Não Cancelou', 'Cancelou'])
plt.tight_layout()
plt.show()

# %% [markdown]
# Por Gastos Mensais

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df_final, x='gastos_mensais', hue='cancelou_servico',
             multiple='stack', palette='coolwarm', kde=True)
plt.xlabel('Gastos Mensais')
plt.ylabel('Contagem de Clientes')
plt.title('Distribuição de Gastos Mensais por Cancelamento (Histograma)')
plt.legend(labels=['Cancelou', 'Não Cancelou'])
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.kdeplot(data=df_final, x='gastos_mensais', hue='cancelou_servico',
            fill=True, common_norm=False, palette='coolwarm')
plt.xlabel('Gastos Mensais')
plt.ylabel('Densidade')
plt.title('Distribuição de Densidade de Gastos Mensais por Cancelamento')
plt.legend(labels=['Não Cancelou', 'Cancelou'])
plt.tight_layout()
plt.show()

# %% [markdown]
# Por Gastos Totais

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))

sns.histplot(data=df_final, x='gastos_totais', hue='cancelou_servico',
             multiple='stack', palette='coolwarm', kde=True)

plt.xlabel('Gastos Totais')
plt.ylabel('Contagem de Clientes')
plt.title('Distribuição de Gastos Totais por Cancelamento (Histograma)')
plt.legend(labels=['Cancelou', 'Não Cancelou'])
plt.tight_layout()
plt.show()

sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))

sns.kdeplot(data=df_final, x='gastos_totais', hue='cancelou_servico',
            fill=True, common_norm=False, palette='coolwarm')

plt.xlabel('Gastos Totais')
plt.ylabel('Densidade')
plt.title('Distribuição de Densidade de Gastos Totais por Cancelamento')
plt.legend(labels=['Não Cancelou', 'Cancelou'])
plt.tight_layout()
plt.show()

# %% [markdown]
# #📄Relatorio Final

# %% [markdown]
# ---
# ## Relatório de Análise de Evasão de Clientes
#
# ### 1. Introdução
#
# A **evasão de clientes**, ou **Churn**, é um desafio central para empresas de telecomunicações. Clientes que cancelam seus serviços representam uma perda direta de receita e podem indicar insatisfação generalizada. Este relatório visa apresentar uma análise exploratória de dados detalhada para identificar os **principais fatores e padrões** que levam os clientes a cancelar seus serviços. O objetivo é fornecer **insights acionáveis** que possam guiar a empresa na formulação de estratégias eficazes de retenção de clientes.
#
# ---
#
# ### 2. Limpeza e Tratamento de Dados
#
# A fase de limpeza e tratamento de dados foi crucial para preparar o conjunto de dados para uma análise robusta e confiável. As principais etapas realizadas foram:
#
# * **Importação e Normalização de Dados:** O conjunto de dados foi inicialmente importado de uma fonte JSON. As colunas que continham informações aninhadas (`customer`, `phone`, `internet`, `account`) foram cuidadosamente normalizadas, e seus dados foram integrados ao DataFrame principal, eliminando a complexidade das estruturas originais.
# * **Tratamento de Dados Faltantes e Inconsistências:**
#     * A coluna **`Churn`** (renomeada posteriormente para `cancelou_servico`), a variável alvo da nossa análise, apresentava valores vazios. As linhas com esses valores foram removidas para garantir a integridade da análise.
#     * A coluna **`Charges.Total`** (renomeada para `gastos_totais`) continha valores vazios quando o `tenure` (meses de serviço) do cliente era zero. Nesses casos, o valor foi preenchido com o `Charges.Monthly` (gastos mensais), representando o gasto inicial do cliente. Após esse ajuste, a coluna foi convertida para o tipo numérico (float64) para permitir cálculos e análises adequadas.
# * **Criação de Novas Variáveis:** Para enriquecer a análise, foi criada a coluna **`gastos_diarios`**, calculada a partir da divisão dos `gastos_mensais` por 30 dias, oferecendo uma nova perspectiva sobre o padrão de consumo.
# * **Padronização de Variáveis Categóricas:** Colunas que apresentavam respostas textuais como "Yes"/"No" (ou suas variações como "No internet service", "No phone service") foram convertidas para um formato binário numérico (`1` para "Sim" e `0` para "Não" ou "Sem serviço"). Isso incluiu colunas como `tem_parceiro`, `tem_dependentes`, `fatura_online`, `cancelou_servico`, `servico_telefone`, `multiplas_linhas`, e diversas outras relacionadas a serviços (segurança online, backup, etc.), além de `eh_cidadao_senior`.
# * **Renomeação de Colunas:** Para facilitar a compreensão e a comunicação dos resultados, todas as colunas do DataFrame foram renomeadas para o português, adotando um padrão consistente e intuitivo (ex: `tenure` para `meses_de_servico`, `Charges.Monthly` para `gastos_mensais`).
#
# ---
#
# ### 3. Análise Exploratória de Dados (EDA)
#
# A análise exploratória de dados revelou padrões importantes no comportamento dos clientes e sua relação com a evasão.
#
# #### 3.1. Estatísticas Descritivas
#
# A análise inicial das **variáveis numéricas** (`meses_de_servico`, `gastos_mensais`, `gastos_totais`, `gastos_diarios`) mostrou a amplitude dos valores, médias e desvios padrão, fornecendo uma visão geral da distribuição do consumo e tempo de contrato dos clientes. Para as **variáveis categóricas**, a contagem de frequência e as porcentagens revelaram a proporção de clientes em cada segmento, como a distribuição de gênero, cidadãos seniores, tipos de contrato e métodos de pagamento. Foi observado um desbalanceamento na variável `cancelou_servico`, com a maioria dos clientes não tendo cancelado o serviço.
#
# #### 3.2. Distribuição de Churn
#
# A visualização da distribuição da variável `cancelou_servico` (Churn) confirmou que a maioria dos clientes permanece com a empresa. Aproximadamente **73.4% dos clientes não cancelaram** o serviço, enquanto **26.6% realizaram o cancelamento**. Este desbalanceamento é um ponto importante a ser considerado em futuras etapas de modelagem.
#
# #### 3.3. Churn por Variáveis Categóricas
#
# A análise da evasão em relação a diferentes categorias revelou insights valiosos:
#
# * **Gênero:** Não foi observada uma diferença significativa na taxa de churn entre homens e mulheres. O gênero, por si só, não parece ser um fator preditivo forte para o cancelamento de serviço.
# * **Serviço de Internet:** Clientes que utilizam **Fibra Óptica** apresentaram uma taxa de churn notavelmente mais alta em comparação com aqueles que usam DSL ou não possuem serviço de internet. Isso pode indicar problemas de satisfação com a velocidade, estabilidade ou expectativas do serviço de fibra.
# * **Tipo de Contrato:** Existe uma forte correlação entre o tipo de contrato e a taxa de churn. Clientes com **contratos mensais** têm uma probabilidade significativamente maior de cancelar o serviço do que aqueles com contratos de um ou dois anos. Contratos de longo prazo demonstraram ser um forte indicativo de retenção.
# * **Método de Pagamento:** Clientes que utilizam **cheque eletrônico** como método de pagamento apresentaram uma taxa de churn mais elevada em comparação com outros métodos como cheque enviado pelo correio ou cartão de crédito. Isso pode estar relacionado à percepção de segurança, praticidade ou a um perfil de cliente mais propenso ao cancelamento.
# * **Cidadão Sênior, Parceiro e Dependentes:** Clientes que são **cidadãos seniores** mostraram uma tendência ligeiramente maior a cancelar. Similarmente, clientes **sem parceiro ou sem dependentes** exibiram taxas de churn mais elevadas, sugerindo que laços familiares podem influenciar a decisão de permanecer com o serviço.
#
# #### 3.4. Churn por Variáveis Numéricas
#
# A exploração das variáveis numéricas, utilizando histogramas e gráficos de densidade (KDE plots), revelou padrões distintos:
#
# * **Meses de Serviço (`meses_de_servico`):** Clientes que cancelaram o serviço tendem a ter um **tempo de serviço consideravelmente menor**. A distribuição de `meses_de_servico` para clientes que cancelaram é fortemente concentrada nos primeiros meses, indicando que a decisão de churn muitas vezes ocorre no início do relacionamento com a empresa.
# * **Gastos Mensais (`gastos_mensais`):** Observou-se que clientes com **gastos mensais mais elevados** (especialmente aqueles na faixa de $70 a $100) têm uma proporção maior de churn em comparação com os de gastos mais baixos. Isso pode estar ligado à expectativa de valor pelo preço pago.
# * **Gastos Totais (`gastos_totais`):** A distribuição dos `gastos_totais` para clientes que cancelaram é visivelmente concentrada em **valores mais baixos**, o que é consistente com o menor tempo de serviço. Clientes com altos gastos totais (e, por inferência, maior tempo de serviço) são menos propensos a cancelar.
#
# ---
#
# ### 4. Conclusões e Insights
#
# Esta análise exploratória de dados forneceu insights cruciais sobre os fatores que impulsionam a evasão de clientes:
#
# * **Contratos Mensais são de Alto Risco:** Clientes com contratos de mês a mês são os mais propensos a cancelar, indicando uma falta de comprometimento a longo prazo ou maior flexibilidade para mudar de provedor.
# * **Problemas com Fibra Óptica:** A alta taxa de churn entre usuários de Fibra Óptica sugere que, apesar de ser um serviço premium, pode haver questões de satisfação ou expectativas não atendidas.
# * **Fase Crítica nos Primeiros Meses:** O tempo de serviço é um forte preditor; clientes com poucos meses de contrato são mais vulneráveis ao churn, destacando a importância de uma forte estratégia de integração e retenção inicial.
# * **Gastos Elevados e Churn:** Clientes com gastos mensais mais altos estão mais inclinados ao churn, talvez por serem mais exigentes em relação ao custo-benefício ou por serem alvo de ofertas mais competitivas de concorrentes.
# * **Métodos de Pagamento e Perfil do Cliente:** O uso de cheque eletrônico como método de pagamento pode ser um indicador de um perfil de cliente com maior propensão à evasão.
#
# Esses achados são valiosos para a empresa, pois direcionam os esforços de retenção para os segmentos de clientes mais vulneráveis.
#
# ---
#
# ### 5. Recomendações
#
# Com base nos insights obtidos, as seguintes recomendações são propostas para mitigar a evasão de clientes:
#
# * **Incentivar Contratos de Longo Prazo:** Criar programas de incentivo atraentes (descontos, benefícios exclusivos) para que clientes com contratos mensais migrem para planos anuais ou bianuais.
# * **Monitoramento e Melhoria da Qualidade da Fibra Óptica:** Realizar uma investigação aprofundada sobre a experiência dos usuários de Fibra Óptica para identificar e corrigir possíveis problemas de serviço que possam estar impulsionando o churn.
# * **Programa de Boas-Vindas e Engajamento Inicial:** Implementar um programa robusto para novos clientes, especialmente nos primeiros 6 meses de serviço, com acompanhamento proativo, suporte técnico prioritário e ofertas personalizadas para aumentar a satisfação e o vínculo.
# * **Análise de Rentabilidade e Precificação:** Avaliar a precificação e o valor percebido dos planos de maior custo, considerando que clientes com gastos mais altos também são mais propensos ao churn. Podem ser oferecidos pacotes de valor agregado ou um programa de fidelidade para esses clientes.
# * **Otimização dos Métodos de Pagamento:** Incentivar o uso de métodos de pagamento alternativos ao cheque eletrônico, talvez através de campanhas de conscientização sobre a comodidade de outros métodos ou pequenos bônus.
# * **Pesquisas de Satisfação Contínuas:** Implementar pesquisas de satisfação em pontos críticos do ciclo de vida do cliente (ex: após 3 meses de serviço, após contato com o suporte) para capturar feedback e resolver problemas proativamente.
#
# Ao focar nesses pontos de dor identificados, a empresa pode desenvolver estratégias de retenção mais eficazes e, consequentemente, reduzir sua taxa de evasão de clientes.
#
# ---
